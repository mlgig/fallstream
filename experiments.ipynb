# %% [markdown]
# ### Imports

# %%
import pandas as pd
df = pd.read_pickle("data/farseeing.pkl").reset_index(drop=True)
df
# Out:
#     SubjectID        FallID freq  \
# 0    97097674  97097674-01b  100
# 1    19120623   19120623-07  100
# 2    51699609   51699609-07  100
# 3    19120623  19120623-02b  100
# 4    74827807   74827807-05  100
# ..        ...           ...  ...
# 140  93807530   93807530-07  100
# 141  66280673   66280673-21  100
# 142  74827807   74827807-07  100
# 143  13638783   13638783-01  100
# 144  08332163   08332163-10  100
#
#                                                  accel  \
# 0    [[-0.4064817203979572, 0.05932878428732201, 0....
# 1    [[0.03329121862526047, 0.007122609395697303, 1...
# 2    [[-0.02896272524815358, 0.05863351020408163, 0...
# 3    [[0.7392387146148207, -0.0808493045852414, 0.7...
# 4    [[-0.027106935617573966, 0.0928192960493755, 1...
# ..                                                 ...
# 140  [[-0.2512998513869559, 0.1097041718423066, 0.8...
# 141  [[0.9684801214513133, -0.09937023299881381, 0....
# 142  [[-0.09020823445657337, -0.13098356821238527, ...
# 143  [[-0.4272355102040817, -0.08658826530612244, 0...
# 144  [[0.04634133203070363, 0.01743632410496619, 0....
#
#                                              accel_mag fall_point
# 0    [0.6725176425850026, 0.6739521067259318, 0.675...      60000
# 1    [0.7849155586122574, 0.7852532201754361, 0.785...      60000
# 2    [0.7339994784866508, 0.7336878877434867, 0.733...      60000
# 3    [0.7828328664638373, 0.7820938011931364, 0.785...      50063
# 4    [0.9423329756019329, 0.9432559565508084, 0.943...      58719
# ..                                                 ...        ...
# 140  [0.7621907825370271, 0.7543021844620563, 0.755...      60000
# 141  [0.40854809628378197, 0.4101299427326448, 0.41...      60000
# 142  [0.5548980949352642, 0.5537446288874992, 0.549...      60000
# 143  [0.5989849845238446, 0.5935731220337921, 0.609...      60000
# 144  [0.732169400329161, 0.7336286879261633, 0.7349...      60000
#
# [145 rows x 6 columns]

# %%
# save to csv
df.to_csv("data/farseeing.csv", index=False)

# %%
df.to_feather("data/farseeing.feather")

# %%
df2 = pd.read_feather("data/farseeing.feather")

# %%
import joblib, json, time, numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
# %load_ext autoreload
# %autoreload 2
from scripts import farseeing as fs
from scripts import utils
from scripts.models import get_model_specs
from scripts.model_runner import run_models
from scripts.metric import compute_row, aggregate
from scripts.plotting import metric_grid, metric_box

# Directories
RES_DIR = Path("results"); RES_DIR.mkdir(exist_ok=True)
FIG_DIR = Path("figs"); FIG_DIR.mkdir(exist_ok=True)
CACHE = RES_DIR / "model_cache"; CACHE.mkdir(exist_ok=True)

# %% [markdown]
# ### Experiment Grid

# %%
WINDOW_SIZES = [3, 5, 7, 10, 15, 30, 60] # seconds
MODEL_SPECS = get_model_specs() # all models
# SEEDS = np.random.RandomState(14).choice(
# 	np.arange(10), size=3, replace=False).tolist()
SEEDS = [0, 1, 2] # for reproducibility
CV_FOLDS = 5
WINDOW_FREQ = 100 #Hz
print(f"Random seeds: {SEEDS}")
# Out:
# Random seeds: [0, 1, 2]

# %% [markdown]
# ### Train/Test Subject Split
# To avoid data leakage, we separate some subjects for final testing and use the training set only for cross-validation.

# %%
# Load train and test data if available, otherwise compute
try:
	subjects = json.load((open(RES_DIR/"subjects.json", "r")))
	TRAIN_SUBJ = subjects['train']
	TEST_SUBJ = subjects['test']
	print("Loaded train/test subjects from subjects.json")
except FileNotFoundError:
	print("No subjects.json found, computing train/test split...")
	TRAIN_SUBJ, TEST_SUBJ = utils.train_test_subjects_split(
		fs, test_size=0.2, random_state=42)
	json.dump({"train": TRAIN_SUBJ.tolist(), "test": TEST_SUBJ.tolist()},
			  open(RES_DIR/"subjects.json", "w"))
# Out:
# Loaded train/test subjects from subjects.json

# %% [markdown]
# ### Initial Cross-validation and Window Size Selection

# %%
train_df = fs.load().query("SubjectID in @TRAIN_SUBJ")

# %% [markdown]
# Baseline models

# %%
from scripts.cv_runner import CVRunner

dummy_specs = get_model_specs(kind="baseline")
DUMMY_CV_ROWS = []
kwargs = dict(
	multiphase=True,
	segment_test=False,
	thresh=1.4
)
run_kwargs = dict(
	verbose=True,
    model_specs=dummy_specs,
    ensemble_models=True,         
    ensemble_by_kind=True                  
)

for win in WINDOW_SIZES:
	print(f"Running CV for window size {win} seconds")
	runner = CVRunner(
        df=train_df,
        dataset=fs,
        groups="SubjectID",
        split_df_fn=utils.split_df,
        run_models_fn=run_models,
        window_size=win,
        cv=CV_FOLDS,
        kwargs=kwargs
    )
	dummy_fold_df = runner.run(**run_kwargs)
	dummy_fold_df["window_size"] = win
	DUMMY_CV_ROWS.append(dummy_fold_df)
dummy_cv_metrics = pd.concat(DUMMY_CV_ROWS, ignore_index=True)
dummy_cv_metrics.to_csv(RES_DIR / "dummy_cv_all_windows.csv", index=False)
# Out:
# Running CV for window size 3 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (1080, 300), y: (1080,)    ([ADLs, Falls]) [978 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1140, 300), y: (1140,)    ([ADLs, Falls]) [1053   87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (969, 300), y: (969,)    ([ADLs, Falls]) [856 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1182, 300), y: (1182,)    ([ADLs, Falls]) [1074  108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (713, 300), y: (713,)    ([ADLs, Falls]) [627  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
# Running CV for window size 5 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (1063, 500), y: (1063,)    ([ADLs, Falls]) [961 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1124, 500), y: (1124,)    ([ADLs, Falls]) [1037   87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (949, 500), y: (949,)    ([ADLs, Falls]) [836 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1165, 500), y: (1165,)    ([ADLs, Falls]) [1057  108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (703, 500), y: (703,)    ([ADLs, Falls]) [617  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
# Running CV for window size 7 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (1052, 700), y: (1052,)    ([ADLs, Falls]) [950 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1114, 700), y: (1114,)    ([ADLs, Falls]) [1027   87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (940, 700), y: (940,)    ([ADLs, Falls]) [827 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1154, 700), y: (1154,)    ([ADLs, Falls]) [1046  108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (700, 700), y: (700,)    ([ADLs, Falls]) [614  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
# Running CV for window size 10 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (1027, 1000), y: (1027,)    ([ADLs, Falls]) [925 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1090, 1000), y: (1090,)    ([ADLs, Falls]) [1003   87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (918, 1000), y: (918,)    ([ADLs, Falls]) [805 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1129, 1000), y: (1129,)    ([ADLs, Falls]) [1021  108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (688, 1000), y: (688,)    ([ADLs, Falls]) [602  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
# Running CV for window size 15 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (998, 1500), y: (998,)    ([ADLs, Falls]) [896 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1057, 1500), y: (1057,)    ([ADLs, Falls]) [970  87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (889, 1500), y: (889,)    ([ADLs, Falls]) [776 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1096, 1500), y: (1096,)    ([ADLs, Falls]) [988 108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (676, 1500), y: (676,)    ([ADLs, Falls]) [590  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
# Running CV for window size 30 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (957, 3000), y: (957,)    ([ADLs, Falls]) [855 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1018, 3000), y: (1018,)    ([ADLs, Falls]) [931  87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (847, 3000), y: (847,)    ([ADLs, Falls]) [734 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1057, 3000), y: (1057,)    ([ADLs, Falls]) [949 108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (657, 3000), y: (657,)    ([ADLs, Falls]) [571  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
# Running CV for window size 60 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (864, 6000), y: (864,)    ([ADLs, Falls]) [762 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (927, 6000), y: (927,)    ([ADLs, Falls]) [840  87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (771, 6000), y: (771,)    ([ADLs, Falls]) [658 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (973, 6000), y: (973,)    ([ADLs, Falls]) [865 108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (621, 6000), y: (621,)    ([ADLs, Falls]) [535  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) ✅
# TESTING DummyADL_0. DummyFall_0. ✅

# %% [markdown]
# Real models

# %%
ALL_CV_ROWS = []
run_kwargs.update(model_specs=MODEL_SPECS,
				  tune_threshold=True)

for win in WINDOW_SIZES:
	print(f"Running CV for window size {win} seconds")
	runner = CVRunner(
        df=train_df,
        dataset=fs,
        groups="SubjectID",
        split_df_fn=utils.split_df,
        run_models_fn=run_models,
        window_size=win,
        cv=CV_FOLDS,
        kwargs=kwargs
    )
	fold_df = runner.run(**run_kwargs)
	fold_df["window_size"] = win
	ALL_CV_ROWS.append(fold_df)
cv_metrics = pd.concat(ALL_CV_ROWS, ignore_index=True)
cv_metrics.to_csv(RES_DIR / "cv_all_windows_tuned.csv", index=False)
# Out:
# Running CV for window size 3 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (1080, 300), y: (1080,)    ([ADLs, Falls]) [978 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) LogisticCV. thresh=0.26 RandomForest. thresh=0.32 ExtraTrees. thresh=0.31 Rocket. thresh=0.01 Catch22. thresh=0.30 QUANT. thresh=0.33 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1140, 300), y: (1140,)    ([ADLs, Falls]) [1053   87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) LogisticCV. thresh=0.21 RandomForest. thresh=0.37 ExtraTrees. thresh=0.35 Rocket. thresh=0.01 Catch22. thresh=0.32 QUANT. thresh=0.43 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (969, 300), y: (969,)    ([ADLs, Falls]) [856 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) LogisticCV. thresh=0.28 RandomForest. thresh=0.41 ExtraTrees. thresh=0.33 Rocket. thresh=0.01 Catch22. thresh=0.38 QUANT. thresh=0.33 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1182, 300), y: (1182,)    ([ADLs, Falls]) [1074  108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) LogisticCV. thresh=0.33 RandomForest. thresh=0.33 ExtraTrees. thresh=0.32 Rocket. thresh=0.01 Catch22. thresh=0.31 QUANT. thresh=0.32 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (713, 300), y: (713,)    ([ADLs, Falls]) [627  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) LogisticCV. thresh=0.37 RandomForest. thresh=0.42 ExtraTrees. thresh=0.35 Rocket. thresh=0.01 Catch22. thresh=0.41 QUANT. thresh=0.28 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
# Running CV for window size 5 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (1063, 500), y: (1063,)    ([ADLs, Falls]) [961 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) LogisticCV. thresh=0.38 RandomForest. thresh=0.46 ExtraTrees. thresh=0.38 Rocket. thresh=0.01 Catch22. thresh=0.47 QUANT. thresh=0.36 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1124, 500), y: (1124,)    ([ADLs, Falls]) [1037   87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) LogisticCV. thresh=0.30 RandomForest. thresh=0.39 ExtraTrees. thresh=0.39 Rocket. thresh=0.01 Catch22. thresh=0.35 QUANT. thresh=0.44 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (949, 500), y: (949,)    ([ADLs, Falls]) [836 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) LogisticCV. thresh=0.28 RandomForest. thresh=0.36 ExtraTrees. thresh=0.30 Rocket. thresh=0.01 Catch22. thresh=0.35 QUANT. thresh=0.30 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1165, 500), y: (1165,)    ([ADLs, Falls]) [1057  108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) LogisticCV. thresh=0.26 RandomForest. thresh=0.29 ExtraTrees. thresh=0.38 Rocket. thresh=0.01 Catch22. thresh=0.46 QUANT. thresh=0.42 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (703, 500), y: (703,)    ([ADLs, Falls]) [617  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) LogisticCV. thresh=0.28 RandomForest. thresh=0.42 ExtraTrees. thresh=0.42 Rocket. thresh=0.01 Catch22. thresh=0.32 QUANT. thresh=0.35 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
# Running CV for window size 7 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (1052, 700), y: (1052,)    ([ADLs, Falls]) [950 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) LogisticCV. thresh=0.38 RandomForest. thresh=0.41 ExtraTrees. thresh=0.36 Rocket. thresh=0.01 Catch22. thresh=0.30 QUANT. thresh=0.33 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1114, 700), y: (1114,)    ([ADLs, Falls]) [1027   87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) LogisticCV. thresh=0.45 RandomForest. thresh=0.48 ExtraTrees. thresh=0.40 Rocket. thresh=0.01 Catch22. thresh=0.36 QUANT. thresh=0.47 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (940, 700), y: (940,)    ([ADLs, Falls]) [827 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) LogisticCV. thresh=0.22 RandomForest. thresh=0.35 ExtraTrees. thresh=0.37 Rocket. thresh=0.01 Catch22. thresh=0.36 QUANT. thresh=0.34 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1154, 700), y: (1154,)    ([ADLs, Falls]) [1046  108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) LogisticCV. thresh=0.21 RandomForest. thresh=0.41 ExtraTrees. thresh=0.37 Rocket. thresh=0.01 Catch22. thresh=0.43 QUANT. thresh=0.33 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (700, 700), y: (700,)    ([ADLs, Falls]) [614  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) LogisticCV. thresh=0.45 RandomForest. thresh=0.44 ExtraTrees. thresh=0.32 Rocket. thresh=0.01 Catch22. thresh=0.32 QUANT. thresh=0.31 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
# Running CV for window size 10 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (1027, 1000), y: (1027,)    ([ADLs, Falls]) [925 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) LogisticCV. thresh=0.27 RandomForest. thresh=0.47 ExtraTrees. thresh=0.33 Rocket. thresh=0.01 Catch22. thresh=0.37 QUANT. thresh=0.32 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1090, 1000), y: (1090,)    ([ADLs, Falls]) [1003   87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) LogisticCV. thresh=0.43 RandomForest. thresh=0.47 ExtraTrees. thresh=0.34 Rocket. thresh=0.01 Catch22. thresh=0.34 QUANT. thresh=0.39 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (918, 1000), y: (918,)    ([ADLs, Falls]) [805 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) LogisticCV. thresh=0.21 RandomForest. thresh=0.40 ExtraTrees. thresh=0.33 Rocket. thresh=0.01 Catch22. thresh=0.37 QUANT. thresh=0.34 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1129, 1000), y: (1129,)    ([ADLs, Falls]) [1021  108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) LogisticCV. thresh=0.23 RandomForest. thresh=0.41 ExtraTrees. thresh=0.34 Rocket. thresh=0.01 Catch22. thresh=0.44 QUANT. thresh=0.35 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (688, 1000), y: (688,)    ([ADLs, Falls]) [602  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) LogisticCV. thresh=0.30 RandomForest. thresh=0.41 ExtraTrees. thresh=0.35 Rocket. thresh=0.01 Catch22. thresh=0.32 QUANT. thresh=0.37 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
# Running CV for window size 15 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (998, 1500), y: (998,)    ([ADLs, Falls]) [896 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) LogisticCV. thresh=0.25 RandomForest. thresh=0.44 ExtraTrees. thresh=0.38 Rocket. thresh=0.01 Catch22. thresh=0.44 QUANT. thresh=0.46 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1057, 1500), y: (1057,)    ([ADLs, Falls]) [970  87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) LogisticCV. thresh=0.47 RandomForest. thresh=0.47 ExtraTrees. thresh=0.51 Rocket. thresh=0.01 Catch22. thresh=0.46 QUANT. thresh=0.52 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (889, 1500), y: (889,)    ([ADLs, Falls]) [776 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) LogisticCV. thresh=0.16 RandomForest. thresh=0.35 ExtraTrees. thresh=0.35 Rocket. thresh=0.01 Catch22. thresh=0.35 QUANT. thresh=0.41 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1096, 1500), y: (1096,)    ([ADLs, Falls]) [988 108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) LogisticCV. thresh=0.42 RandomForest. thresh=0.47 ExtraTrees. thresh=0.36 Rocket. thresh=0.01 Catch22. thresh=0.35 QUANT. thresh=0.51 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (676, 1500), y: (676,)    ([ADLs, Falls]) [590  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) LogisticCV. thresh=0.38 RandomForest. thresh=0.41 ExtraTrees. thresh=0.40 Rocket. thresh=0.01 Catch22. thresh=0.40 QUANT. thresh=0.44 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
# Running CV for window size 30 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (957, 3000), y: (957,)    ([ADLs, Falls]) [855 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) LogisticCV. thresh=0.55 RandomForest. thresh=0.42 ExtraTrees. thresh=0.43 Rocket. thresh=0.01 Catch22. thresh=0.34 QUANT. thresh=0.46 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (1018, 3000), y: (1018,)    ([ADLs, Falls]) [931  87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) LogisticCV. thresh=0.26 RandomForest. thresh=0.45 ExtraTrees. thresh=0.38 Rocket. thresh=0.01 Catch22. thresh=0.39 QUANT. thresh=0.52 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 3/5: testing on 6 subjects –
# Train set: 113 samples, Test set: 11 samples
# Train set: X: (847, 3000), y: (847,)    ([ADLs, Falls]) [734 113]
# Test set: X: 11, y: 11
# TRAINING (seed=0) LogisticCV. thresh=0.21 RandomForest. thresh=0.39 ExtraTrees. thresh=0.38 Rocket. thresh=0.01 Catch22. thresh=0.46 QUANT. thresh=0.42 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 4/5: testing on 6 subjects –
# Train set: 108 samples, Test set: 16 samples
# Train set: X: (1057, 3000), y: (1057,)    ([ADLs, Falls]) [949 108]
# Test set: X: 16, y: 16
# TRAINING (seed=0) LogisticCV. thresh=0.27 RandomForest. thresh=0.42 ExtraTrees. thresh=0.41 Rocket. thresh=0.01 Catch22. thresh=0.42 QUANT. thresh=0.45 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 5/5: testing on 6 subjects –
# Train set: 86 samples, Test set: 38 samples
# Train set: X: (657, 3000), y: (657,)    ([ADLs, Falls]) [571  86]
# Test set: X: 38, y: 38
# TRAINING (seed=0) LogisticCV. thresh=0.32 RandomForest. thresh=0.34 ExtraTrees. thresh=0.40 Rocket. thresh=0.01 Catch22. thresh=0.39 QUANT. thresh=0.45 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
# Running CV for window size 60 seconds
#
# – Fold 1/5: testing on 7 subjects –
# Train set: 102 samples, Test set: 22 samples
# Train set: X: (864, 6000), y: (864,)    ([ADLs, Falls]) [762 102]
# Test set: X: 22, y: 22
# TRAINING (seed=0) LogisticCV. thresh=0.07 RandomForest. thresh=0.45 ExtraTrees. thresh=0.40 Rocket. thresh=0.01 Catch22. thresh=0.50 QUANT. thresh=0.38 ✅
# TESTING DummyADL_0. DummyFall_0. LogisticCV_0. RandomForest_0. ExtraTrees_0. Rocket_0. Catch22_0. QUANT_0. ✅
#
# – Fold 2/5: testing on 7 subjects –
# Train set: 87 samples, Test set: 37 samples
# Train set: X: (927, 6000), y: (927,)    ([ADLs, Falls]) [840  87]
# Test set: X: 37, y: 37
# TRAINING (seed=0) LogisticCV. thresh=0.22 RandomForest. thresh=0.40 ExtraTrees. thresh=0.46 Rocket. thresh=0.01 Catch22.

# %%
real_cv_metrics = pd.read_csv(RES_DIR / "cv_all_windows_tuned.csv")
dummy_cv_metrics = pd.read_csv(RES_DIR / "dummy_cv_all_windows.csv")
all_cv_metrics = pd.concat([real_cv_metrics, dummy_cv_metrics], ignore_index=True)
all_cv_metrics
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 real_cv_metrics = pd.read_csv(RES_DIR / "cv_all_windows_tuned.csv")
#       2 dummy_cv_metrics = pd.read_csv(RES_DIR / "dummy_cv_all_windows.csv")
#       3 all_cv_metrics = pd.concat([real_cv_metrics, dummy_cv_metrics], ignore_index=True)
#
# File /mnt/storage/timiderinola/miniconda3/envs/msca/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /mnt/storage/timiderinola/miniconda3/envs/msca/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /mnt/storage/timiderinola/miniconda3/envs/msca/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /mnt/storage/timiderinola/miniconda3/envs/msca/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /mnt/storage/timiderinola/miniconda3/envs/msca/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/cv_all_windows_tuned.csv'

# %%
best_rows = (
    all_cv_metrics
    .groupby(["model", "window_size"])
    ["f1-score"].mean()
    .unstack("window_size")
    .idxmax(axis=1) # window with highest mean F1
)
BEST_WINDOW = best_rows.to_dict()
json.dump(BEST_WINDOW, open(RES_DIR/"best_window.json","w"))

# %%
from scripts.plotting import window_bar

plt.figure(figsize=(7, 2), dpi=400)
ax = window_bar(real_cv_metrics.query("seed==0.0"),
                metric="f1-score", ci="sd",
                x="model", hue="window_size")
ax.set_xlabel("Model")
ax.set_title("")
ax.set_ylim(0.4, 0.95)
ax.grid(axis='y', alpha=0.5, which='both')
ax.legend(loc=9, ncol=7, 
          title="win_size (s)",
          bbox_to_anchor=(0.5, 1.5),
          fontsize=10)
ax.set_title("")
plt.savefig(FIG_DIR / "window_bar.pdf", bbox_inches='tight')
plt.show()

# %%
# drop ensemble rows
cv_metrics_no_ensenmble = real_cv_metrics.query("seed == 0.0")
grps = cv_metrics_no_ensenmble.groupby(['model', 'window_size']).mean(numeric_only=True)
# pick best model and window size
best_model = grps['f1-score'].idxmax()[0]
best_window = grps['f1-score'].idxmax()[1]
print(f"Best model: {best_model} with window size of {best_window} seconds")
# Out:
# Best model: QUANT with window size of 10 seconds

# %%
cv_metrics_no_ensenmble
# Out:
#             model  seed  window_size     runtime      delay  precision  \
# 0      LogisticCV   0.0            3    0.205031   4.454545   0.842105
# 1    RandomForest   0.0            3    0.198551   0.045455   0.800000
# 2      ExtraTrees   0.0            3    0.200628   0.909091   0.909091
# 3          Rocket   0.0            3    4.023338   0.545455   0.333333
# 4         Catch22   0.0            3    6.329436   0.772727   0.714286
# ..            ...   ...          ...         ...        ...        ...
# 307  RandomForest   0.0           60    0.501969  -7.201081   0.750000
# 308    ExtraTrees   0.0           60    0.489665  -5.263784   0.837838
# 309        Rocket   0.0           60   57.233424 -27.113243   0.483871
# 310       Catch22   0.0           60  123.774112 -29.194324   0.417910
# 311         QUANT   0.0           60   10.954915   1.427297   0.700000
#
#        recall  specificity  f1-score       auc  false alarm rate  miss rate  \
# 0    0.727273     0.999999  0.780488  0.863636          0.409088   0.818175
# 1    0.909091     0.999998  0.851064  0.954545          0.681813   0.272725
# 2    0.909091     0.999999  0.909091  0.954545          0.272725   0.272725
# 3    0.818182     0.999986  0.473684  0.909084          4.909050   0.545450
# 4    0.909091     0.999997  0.800000  0.954544          1.090900   0.272725
# ..        ...          ...       ...       ...               ...        ...
# 307  0.810811     0.999998  0.779221  0.905404          0.815173   0.570621
# 308  0.837838     0.999999  0.837838  0.918918          0.489104   0.489104
# 309  0.810811     0.999993  0.606061  0.905402          2.608554   0.570621
# 310  0.756757     0.999991  0.538462  0.878374          3.179175   0.733656
# 311  0.756757     0.999997  0.727273  0.878377          0.978208   0.733656
#
#       gain  fold
# 0    0.001     1
# 1    0.001     1
# 2    0.001     1
# 3    0.001     1
# 4    0.001     1
# ..     ...   ...
# 307  0.001     5
# 308  0.001     5
# 309  0.001     5
# 310  0.001     5
# 311  0.001     5
#
# [210 rows x 14 columns]

# %%
# use multiple comparison matrix from aeon
from aeon.visualisation import create_multi_comparison_matrix

pivots = cv_metrics_no_ensenmble.pivot_table(
    index='fold',
    columns='model',
	values='f1-score',
    aggfunc='mean'
)
pivots
# Out:
# model   Catch22  ExtraTrees  LogisticCV     QUANT  RandomForest    Rocket
# fold
# 1      0.683856    0.934002    0.791777  0.854347      0.834682  0.492852
# 2      0.771202    0.815350    0.800376  0.866292      0.797511  0.576047
# 3      0.455554    0.698955    0.685119  0.798997      0.693376  0.637290
# 4      0.738308    0.693970    0.770282  0.832795      0.719503  0.637701
# 5      0.561880    0.742415    0.621768  0.770772      0.683981  0.562416

# %%
create_multi_comparison_matrix(pivots,
                               used_statistic='F1-score',
                            #    win_label='wins',
                            #    loss_label='losses',
                            #    tie_label='ties',
                               font_size=19,
                               fig_size="20,10",
                               pdf_savename=FIG_DIR / "multi_comparison_matrix.pdf")
plt.show()

# %% [markdown]
# ### Cost Sensitive Threshold Tuning

# %%
best_windows = json.load(open(RES_DIR/"best_window.json", "r"))
win_sizes = set([best_windows[m.name] for m in MODEL_SPECS\
                  if m.kind != "baseline" and "Ensemble" not in m.name])
# create datasets for each window size
whole_df = fs.load()
datasets = {}
for win in win_sizes:
    datasets[win] = utils.split_df(
		whole_df, fs, test_set=TEST_SUBJ,
        window_size=win, segment_test=False,
        thresh=1.4, multiphase=True
	)
# Out:
# Train set: 124 samples, Test set: 21 samples
# Train set: X: (1213, 1000), y: (1213,)    ([ADLs, Falls]) [1089  124]
# Test set: X: 21, y: 21
# Train set: 124 samples, Test set: 21 samples
# Train set: X: (1039, 6000), y: (1039,)    ([ADLs, Falls]) [915 124]
# Test set: X: 21, y: 21
# Train set: 124 samples, Test set: 21 samples
# Train set: X: (1240, 700), y: (1240,)    ([ADLs, Falls]) [1116  124]
# Test set: X: 21, y: 21

# %%
from scripts.model_runner import run_models

thresh_metrics = []
baselines = get_model_specs(kind="baseline")
for t in [False, True]:
	print(f"\nRunning with thresh={t}")
	temp_specs = get_model_specs(subset=['QUANT'])
	models = [m for m in temp_specs if m.kind != "baseline"]
	if not t and models != []:
		models += baselines
	print(f"Selected models: {[m.name for m in models]}")
	X_tr, X_te, y_tr, y_te = datasets[60]
	res = run_models(
		X_tr, X_te, y_tr, y_te,
		model_specs=models,
		# model_seeds=SEEDS,
		verbose=True,
		ensemble_models=False,
		ensemble_by_kind=False,
		window_size=60,
		tune_threshold=t
	)
	res["window_size"] = 60
	thresh_metrics.append(res)
thresh_df = pd.concat(thresh_metrics, ignore_index=True)
thresh_df.to_csv(RES_DIR / "thresh_metrics.csv", index=False)
# Out:
# Running with thresh=False
# Selected models: ['QUANT', 'DummyADL', 'DummyFall']
# TRAINING (seed=0) QUANT. ✅
# TESTING QUANT_0. DummyADL_0. DummyFall_0. ✅
#
# Running with thresh=True
# Selected models: ['QUANT']
# TRAINING (seed=0) QUANT. thresh=0.52 ✅
# TESTING QUANT_0. ✅

# %%
from scripts.model_runner import run_models

thresh_metrics = []
baselines = get_model_specs(kind="baseline")
for t in [False, True]:
	for win in win_sizes:
		print(f"Running models for window size {win} seconds, thresh={t}")
		# Select models for this window size
		models = [m for m in MODEL_SPECS
			 if m.kind != "baseline"
				  and best_windows[m.name] == win]
		if not t and models != []:
			models += baselines
		print(f"Selected models: {[m.name for m in models]}")
		X_tr, X_te, y_tr, y_te = datasets[win]
		res = run_models(
			X_tr, X_te, y_tr, y_te,
			model_specs=models,
			model_seeds=SEEDS,
			verbose=True,
			ensemble_models=False,
			ensemble_by_kind=False,
			window_size=win,
			tune_threshold=t
		)
		res["window_size"] = win
		thresh_metrics.append(res)
thresh_df = pd.concat(thresh_metrics, ignore_index=True)
thresh_df.to_csv(RES_DIR / "thresh_metrics.csv", index=False)
# Out:
# Running models for window size 10 seconds, thresh=False
# Selected models: ['Catch22', 'QUANT', 'DummyADL', 'DummyFall']
# TRAINING (seed=0) Catch22. QUANT. ✅
# TRAINING (seed=1) Catch22. QUANT. ✅
# TRAINING (seed=2) Catch22. QUANT. ✅
# TESTING Catch22_0. QUANT_0. DummyADL_0. DummyFall_0. Catch22_1. QUANT_1. Catch22_2. QUANT_2. ✅
# Running models for window size 60 seconds, thresh=False
# Selected models: ['RandomForest', 'ExtraTrees', 'Rocket', 'DummyADL', 'DummyFall']
# TRAINING (seed=0) RandomForest. ExtraTrees. Rocket. ✅
# TRAINING (seed=1) RandomForest. ExtraTrees. Rocket. ✅
# TRAINING (seed=2) RandomForest. ExtraTrees. Rocket. ✅
# TESTING RandomForest_0. ExtraTrees_0. Rocket_0. DummyADL_0. DummyFall_0. RandomForest_1. ExtraTrees_1. Rocket_1. RandomForest_2. ExtraTrees_2. Rocket_2. ✅
# Running models for window size 7 seconds, thresh=False
# Selected models: ['LogisticCV', 'DummyADL', 'DummyFall']
# TRAINING (seed=0) LogisticCV. ✅
# TRAINING (seed=1) LogisticCV. ✅
# TRAINING (seed=2) LogisticCV. ✅
# TESTING LogisticCV_0. DummyADL_0. DummyFall_0. LogisticCV_1. LogisticCV_2. ✅
# Running models for window size 10 seconds, thresh=True
# Selected models: ['Catch22', 'QUANT']
# TRAINING (seed=0) Catch22. thresh=0.38 QUANT. thresh=0.40 ✅
# TRAINING (seed=1) Catch22. QUANT. ✅
# TRAINING (seed=2) Catch22. QUANT. ✅
# TESTING Catch22_0. QUANT_0. Catch22_1. QUANT_1. Catch22_2. QUANT_2. ✅
# Running models for window size 60 seconds, thresh=True
# Selected models: ['RandomForest', 'ExtraTrees', 'Rocket']
# TRAINING (seed=0) RandomForest. thresh=0.46 ExtraTrees. thresh=0.48 Rocket. thresh=0.01 ✅
# TRAINING (seed=1) RandomForest. ExtraTrees. Rocket. ✅
# TRAINING (seed=2) RandomForest. ExtraTrees. Rocket. ✅
# TESTING RandomForest_0. ExtraTrees_0. Rocket_0. RandomForest_1. ExtraTrees_1. Rocket_1. RandomForest_2. ExtraTrees_2. Rocket_2. ✅
# Running models for window size 7 seconds, thresh=True
# Selected models: ['LogisticCV']
# TRAINING (seed=0) LogisticCV. thresh=0.47 ✅
# TRAINING (seed=1) LogisticCV. ✅
# TRAINING (seed=2) LogisticCV. ✅
# TESTING LogisticCV_0. LogisticCV_1. LogisticCV_2. ✅

# %%
from scripts.model_runner import run_models

thresh_metrics = []
# X_tr, X_te, y_tr, y_te = utils.split_df(
# 	whole_df, fs, test_set=TEST_SUBJ,
# 	window_size=27.5, segment_test=False,
# 	thresh=1.4, multiphase=True)

for t in [False, True]:
	for win in [27.5]:
		print(f"Running models for window size {win} seconds, thresh={t}")
		# Select models for this window size
		models = get_model_specs(subset=['QUANT'])
		print(f"Selected models: {[m.name for m in models]}")
		res = run_models(
			X_tr, X_te, y_tr, y_te,
			model_specs=models,
			model_seeds=SEEDS,
			verbose=True,
			ensemble_models=False,
			ensemble_by_kind=False,
			window_size=win,
			tune_threshold=t
		)
		res["window_size"] = win
		thresh_metrics.append(res)
thresh_df = pd.concat(thresh_metrics, ignore_index=True)
thresh_df.to_csv(RES_DIR / "thresh_metrics_275.csv", index=False)
# Out:
# Running models for window size 27.5 seconds, thresh=False
# Selected models: ['QUANT']
# TRAINING (seed=0) QUANT. ✅
# TRAINING (seed=1) QUANT. ✅
# TRAINING (seed=2) QUANT. ✅
# TESTING QUANT_0. QUANT_1. QUANT_2. ✅
# Running models for window size 27.5 seconds, thresh=True
# Selected models: ['QUANT']
# TRAINING (seed=0) QUANT. thresh=0.59 ✅
# TRAINING (seed=1) QUANT. ✅
# TRAINING (seed=2) QUANT. ✅
# TESTING QUANT_0. QUANT_1. QUANT_2. ✅

# %%
thresh_df = pd.read_csv(RES_DIR / "thresh_metrics_275.csv")
thresh_df.sort_values(by=["model", "seed"])
# Out:
#    model  seed  window_size    runtime     delay  precision    recall  \
# 0  QUANT     0         27.5  10.493065 -2.820952   0.791667  0.904762
# 3  QUANT     0         27.5  10.866758  0.512381   0.894737  0.809524
# 1  QUANT     1         27.5  10.728784 -3.059048   0.791667  0.904762
# 4  QUANT     1         27.5  11.054866  0.464762   0.850000  0.809524
# 2  QUANT     2         27.5  10.700540 -3.059048   0.730769  0.904762
# 5  QUANT     2         27.5  10.387561 -0.344762   0.900000  0.857143
#
#    specificity  f1-score       auc  false alarm rate  miss rate      gain  \
# 0     0.999998  0.844444  0.952380          0.717959   0.287184  6.962583
# 3     0.999999  0.850000  0.904762          0.287184   0.574367  6.962581
# 1     0.999998  0.844444  0.952380          0.717959   0.287184  6.962583
# 4     0.999999  0.829268  0.904761          0.430776   0.574367  6.962578
# 2     0.999997  0.808511  0.952380          1.005143   0.287184  6.962577
# 5     0.999999  0.878049  0.928571          0.287184   0.430776  6.962586
#
#      thresh
# 0  0.500000
# 3  0.585859
# 1  0.500000
# 4  0.585859
# 2  0.500000
# 5  0.585859

# %%
thresh_df = pd.read_csv(RES_DIR / "thresh_metrics.csv")
thresh_df.sort_values(by=["model", "seed"])
# Out:
#            model  seed  window_size    runtime      delay  precision  \
# 0        Catch22     0           10  22.751610  -4.106667   0.580645
# 24       Catch22     0           10  22.353587  -4.487619   0.473684
# 4        Catch22     1           10  23.405101  -4.106667   0.600000
# 26       Catch22     1           10  23.361385  -6.344762   0.473684
# 6        Catch22     2           10  24.118133  -5.106667   0.593750
# 28       Catch22     2           10  23.229871  -7.678095   0.513514
# 2       DummyADL     0           10   0.051074  20.000000   0.000000
# 11      DummyADL     0           60   0.101422  20.000000   0.000000
# 20      DummyADL     0            7   0.062258  20.000000   0.000000
# 3      DummyFall     0           10   0.000347   0.000000   0.000084
# 12     DummyFall     0           60   0.000502   0.000000   0.000503
# 21     DummyFall     0            7   0.000613   0.000000   0.000059
# 9     ExtraTrees     0           60   0.711434   3.998095   0.941176
# 31    ExtraTrees     0           60   0.723301   3.998095   0.941176
# 14    ExtraTrees     1           60   0.696780   3.998095   0.888889
# 34    ExtraTrees     1           60   0.979720   3.998095   0.888889
# 17    ExtraTrees     2           60   0.730224   4.569524   0.842105
# 37    ExtraTrees     2           60   0.719851   3.998095   0.842105
# 19    LogisticCV     0            7   0.142866   5.236190   0.833333
# 39    LogisticCV     0            7   0.165479   5.236190   0.833333
# 22    LogisticCV     1            7   0.138787   5.236190   0.833333
# 40    LogisticCV     1            7   0.165775   5.236190   0.833333
# 23    LogisticCV     2            7   0.139250   5.236190   0.833333
# 41    LogisticCV     2            7   0.163632   5.236190   0.833333
# 1          QUANT     0           10   6.511829  -1.582857   0.863636
# 25         QUANT     0           10   7.196987  -3.630476   0.840000
# 5          QUANT     1           10   7.051927  -1.344762   0.826087
# 27         QUANT     1           10   6.741360  -4.916190   0.840000
# 7          QUANT     2           10   7.047256  -1.535238   0.826087
# 29         QUANT     2           10   7.105249  -3.630476   0.807692
# 8   RandomForest     0           60   0.943884  -0.773333   0.850000
# 30  RandomForest     0           60   0.750159  -1.820952   0.857143
# 13  RandomForest     1           60   0.734687  -0.201905   0.850000
# 33  RandomForest     1           60   1.065060  -1.773333   0.857143
# 16  RandomForest     2           60   0.717051   2.093333   0.842105
# 36  RandomForest     2           60   0.760386   0.512381   0.850000
# 10        Rocket     0           60  59.953964 -49.297143   0.452381
# 32        Rocket     0           60  59.665061 -49.297143   0.452381
# 15        Rocket     1           60  59.836241 -47.678095   0.431818
# 35        Rocket     1           60  59.978254 -47.678095   0.431818
# 18        Rocket     2           60  59.625046 -56.963810   0.434783
# 38        Rocket     2           60  59.734027 -56.963810   0.434783
#
#       recall  specificity  f1-score       auc  false alarm rate  miss rate  \
# 0   0.857143     0.999995  0.692308  0.928569          1.866694   0.430776
# 24  0.857143     0.999992  0.610169  0.928567          2.871837   0.430776
# 4   0.857143     0.999995  0.705882  0.928569          1.723102   0.430776
# 26  0.857143     0.999992  0.610169  0.928567          2.871837   0.430776
# 6   0.904762     0.999995  0.716981  0.952378          1.866694   0.287184
# 28  0.904762     0.999993  0.655172  0.952377          2.584653   0.287184
# 2   0.000000     1.000000  0.000000  0.500000          0.000000   3.015429
# 11  0.000000     1.000000  0.000000  0.500000          0.000000   3.015429
# 20  0.000000     1.000000  0.000000  0.500000          0.000000   3.015429
# 3   1.000000     0.000000  0.000168  0.500000      35996.611232   0.000000
# 12  1.000000     0.000000  0.001005  0.500000       5996.826620   0.000000
# 21  1.000000     0.000000  0.000117  0.500000      51425.412408   0.000000
# 9   0.761905     1.000000  0.842105  0.880952          0.143592   0.717959
# 31  0.761905     1.000000  0.842105  0.880952          0.143592   0.717959
# 14  0.761905     0.999999  0.820513  0.880952          0.287184   0.717959
# 34  0.761905     0.999999  0.820513  0.880952          0.287184   0.717959
# 17  0.761905     0.999999  0.800000  0.880952          0.430776   0.717959
# 37  0.761905     0.999999  0.800000  0.880952          0.430776   0.717959
# 19  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 39  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 22  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 40  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 23  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 41  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 1   0.904762     0.999999  0.883721  0.952380          0.430776   0.287184
# 25  1.000000     0.999998  0.913043  0.999999          0.574367   0.000000
# 5   0.904762     0.999998  0.863636  0.952380          0.574367   0.287184
# 27  1.000000     0.999998  0.913043  0.999999          0.574367   0.000000
# 7   0.904762     0.999998  0.863636  0.952380          0.574367   0.287184
# 29  1.000000     0.999998  0.893617  0.999999          0.717959   0.000000
# 8   0.809524     0.999999  0.829268  0.904761          0.430776   0.574367
# 30  0.857143     0.999999  0.857143  0.928571          0.430776   0.430776
# 13  0.809524     0.999999  0.829268  0.904761          0.430776   0.574367
# 33  0.857143     0.999999  0.857143  0.928571          0.430776   0.430776
# 16  0.761905     0.999999  0.800000  0.880952          0.430776   0.717959
# 36  0.809524     0.999999  0.829268  0.904761          0.430776   0.574367
# 10  0.904762     0.999991  0.603175  0.952376          3.302613   0.287184
# 32  0.904762     0.999991  0.603175  0.952376          3.302613   0.287184
# 15  0.904762     0.999990  0.584615  0.952376          3.589796   0.287184
# 35  0.904762     0.999990  0.584615  0.952376          3.589796   0.287184
# 18  0.952381     0.999990  0.597015  0.976185          3.733388   0.143592
# 38  0.952381     0.999990  0.597015  0.976185          3.733388   0.143592
#
#         gain    thresh
# 0   6.963603  0.500000
# 24  6.963582  0.378182
# 4   6.963606  0.500000
# 26  6.963582  0.378182
# 6   6.963608  0.500000
# 28  6.963593  0.378182
# 2   6.963547  0.500000
# 11  6.960630  0.500000
# 20  6.963722  0.500000
# 3  -0.069045  0.500000
# 12 -0.012418  0.500000
# 21 -0.097170  0.500000
# 9   6.960712  0.500000
# 31  6.960712  0.484848
# 14  6.960709  0.500000
# 34  6.960709  0.484848
# 17  6.960706  0.500000
# 37  6.960706  0.484848
# 19  6.963792  0.500000
# 39  6.963792  0.474747
# 22  6.963792  0.500000
# 40  6.963792  0.474747
# 23  6.963792  0.500000
# 41  6.963792  0.474747
# 1   6.963639  0.500000
# 25  6.963646  0.404040
# 5   6.963636  0.500000
# 27  6.963646  0.404040
# 7   6.963636  0.500000
# 29  6.963643  0.404040
# 8   6.960711  0.500000
# 30  6.960717  0.461953
# 13  6.960711  0.500000
# 33  6.960717  0.461953
# 16  6.960706  0.500000
# 36  6.960711  0.461953
# 10  6.960661  0.500000
# 32  6.960661  0.010101
# 15  6.960655  0.500000
# 35  6.960655  0.010101
# 18  6.960658  0.500000
# 38  6.960658  0.010101

# %%
# select where model is dummy
dummy_df = thresh_df.query("model.str.contains('Dummy')", engine='python')
real_thresh_df = thresh_df.query("not model.str.contains('Dummy')", engine='python')
real_thresh_df.sort_values(by=["model", "seed"])
# Out:
#            model  seed  window_size    runtime      delay  precision  \
# 0        Catch22     0           10  22.751610  -4.106667   0.580645
# 24       Catch22     0           10  22.353587  -4.487619   0.473684
# 4        Catch22     1           10  23.405101  -4.106667   0.600000
# 26       Catch22     1           10  23.361385  -6.344762   0.473684
# 6        Catch22     2           10  24.118133  -5.106667   0.593750
# 28       Catch22     2           10  23.229871  -7.678095   0.513514
# 9     ExtraTrees     0           60   0.711434   3.998095   0.941176
# 31    ExtraTrees     0           60   0.723301   3.998095   0.941176
# 14    ExtraTrees     1           60   0.696780   3.998095   0.888889
# 34    ExtraTrees     1           60   0.979720   3.998095   0.888889
# 17    ExtraTrees     2           60   0.730224   4.569524   0.842105
# 37    ExtraTrees     2           60   0.719851   3.998095   0.842105
# 19    LogisticCV     0            7   0.142866   5.236190   0.833333
# 39    LogisticCV     0            7   0.165479   5.236190   0.833333
# 22    LogisticCV     1            7   0.138787   5.236190   0.833333
# 40    LogisticCV     1            7   0.165775   5.236190   0.833333
# 23    LogisticCV     2            7   0.139250   5.236190   0.833333
# 41    LogisticCV     2            7   0.163632   5.236190   0.833333
# 1          QUANT     0           10   6.511829  -1.582857   0.863636
# 25         QUANT     0           10   7.196987  -3.630476   0.840000
# 5          QUANT     1           10   7.051927  -1.344762   0.826087
# 27         QUANT     1           10   6.741360  -4.916190   0.840000
# 7          QUANT     2           10   7.047256  -1.535238   0.826087
# 29         QUANT     2           10   7.105249  -3.630476   0.807692
# 8   RandomForest     0           60   0.943884  -0.773333   0.850000
# 30  RandomForest     0           60   0.750159  -1.820952   0.857143
# 13  RandomForest     1           60   0.734687  -0.201905   0.850000
# 33  RandomForest     1           60   1.065060  -1.773333   0.857143
# 16  RandomForest     2           60   0.717051   2.093333   0.842105
# 36  RandomForest     2           60   0.760386   0.512381   0.850000
# 10        Rocket     0           60  59.953964 -49.297143   0.452381
# 32        Rocket     0           60  59.665061 -49.297143   0.452381
# 15        Rocket     1           60  59.836241 -47.678095   0.431818
# 35        Rocket     1           60  59.978254 -47.678095   0.431818
# 18        Rocket     2           60  59.625046 -56.963810   0.434783
# 38        Rocket     2           60  59.734027 -56.963810   0.434783
#
#       recall  specificity  f1-score       auc  false alarm rate  miss rate  \
# 0   0.857143     0.999995  0.692308  0.928569          1.866694   0.430776
# 24  0.857143     0.999992  0.610169  0.928567          2.871837   0.430776
# 4   0.857143     0.999995  0.705882  0.928569          1.723102   0.430776
# 26  0.857143     0.999992  0.610169  0.928567          2.871837   0.430776
# 6   0.904762     0.999995  0.716981  0.952378          1.866694   0.287184
# 28  0.904762     0.999993  0.655172  0.952377          2.584653   0.287184
# 9   0.761905     1.000000  0.842105  0.880952          0.143592   0.717959
# 31  0.761905     1.000000  0.842105  0.880952          0.143592   0.717959
# 14  0.761905     0.999999  0.820513  0.880952          0.287184   0.717959
# 34  0.761905     0.999999  0.820513  0.880952          0.287184   0.717959
# 17  0.761905     0.999999  0.800000  0.880952          0.430776   0.717959
# 37  0.761905     0.999999  0.800000  0.880952          0.430776   0.717959
# 19  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 39  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 22  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 40  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 23  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 41  0.714286     0.999999  0.769231  0.857142          0.430776   0.861551
# 1   0.904762     0.999999  0.883721  0.952380          0.430776   0.287184
# 25  1.000000     0.999998  0.913043  0.999999          0.574367   0.000000
# 5   0.904762     0.999998  0.863636  0.952380          0.574367   0.287184
# 27  1.000000     0.999998  0.913043  0.999999          0.574367   0.000000
# 7   0.904762     0.999998  0.863636  0.952380          0.574367   0.287184
# 29  1.000000     0.999998  0.893617  0.999999          0.717959   0.000000
# 8   0.809524     0.999999  0.829268  0.904761          0.430776   0.574367
# 30  0.857143     0.999999  0.857143  0.928571          0.430776   0.430776
# 13  0.809524     0.999999  0.829268  0.904761          0.430776   0.574367
# 33  0.857143     0.999999  0.857143  0.928571          0.430776   0.430776
# 16  0.761905     0.999999  0.800000  0.880952          0.430776   0.717959
# 36  0.809524     0.999999  0.829268  0.904761          0.430776   0.574367
# 10  0.904762     0.999991  0.603175  0.952376          3.302613   0.287184
# 32  0.904762     0.999991  0.603175  0.952376          3.302613   0.287184
# 15  0.904762     0.999990  0.584615  0.952376          3.589796   0.287184
# 35  0.904762     0.999990  0.584615  0.952376          3.589796   0.287184
# 18  0.952381     0.999990  0.597015  0.976185          3.733388   0.143592
# 38  0.952381     0.999990  0.597015  0.976185          3.733388   0.143592
#
#         gain    thresh
# 0   6.963603  0.500000
# 24  6.963582  0.378182
# 4   6.963606  0.500000
# 26  6.963582  0.378182
# 6   6.963608  0.500000
# 28  6.963593  0.378182
# 9   6.960712  0.500000
# 31  6.960712  0.484848
# 14  6.960709  0.500000
# 34  6.960709  0.484848
# 17  6.960706  0.500000
# 37  6.960706  0.484848
# 19  6.963792  0.500000
# 39  6.963792  0.474747
# 22  6.963792  0.500000
# 40  6.963792  0.474747
# 23  6.963792  0.500000
# 41  6.963792  0.474747
# 1   6.963639  0.500000
# 25  6.963646  0.404040
# 5   6.963636  0.500000
# 27  6.963646  0.404040
# 7   6.963636  0.500000
# 29  6.963643  0.404040
# 8   6.960711  0.500000
# 30  6.960717  0.461953
# 13  6.960711  0.500000
# 33  6.960717  0.461953
# 16  6.960706  0.500000
# 36  6.960711  0.461953
# 10  6.960661  0.500000
# 32  6.960661  0.010101
# 15  6.960655  0.500000
# 35  6.960655  0.010101
# 18  6.960658  0.500000
# 38  6.960658  0.010101

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4), dpi=400,
					   sharey=True, layout='constrained')
for i, m in enumerate(['miss rate', 'false alarm rate']):
	sns.barplot(data=thresh_df, x='model', y=m, hue='tuned',
			 ax=ax[i], palette='tab10')
	labels1 = [x for x in ax[i].containers[0].datavalues] # Round up container[0] values
	labels2 = [x for x in ax[i].containers[1].datavalues] # Round up container[1] values
	improvements = [np.round(b-a,2) for a, b in zip(labels1, labels2)] # Calculate improvements
	lbls = [f'{i}\nmore' if i > 0 else f'{abs(i)}\nless' for i in improvements]
	# Annotate using rounded values
	ax[i].bar_label(ax[i].containers[1], labels=lbls, fontsize=12.5, padding=2)
	ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45, ha='right')
	m = 'FAR (per hour)' if m == 'false alarm rate' else m
	m = 'MR (per hour)' if m == 'miss rate' else m
	ax[i].set_title(m, pad=10)
	ax[i].set_xlabel('')
	ax[i].set_ylabel('')
	# only show legend for the last plot
	if i > 0:
		ax[i].get_legend().remove()
	else:
		ax[i].legend(title='Threshold', ncols=2)
sns.despine()
# plt.savefig('figs/barplot_tune_threshold_7sec.pdf',
			# dpi=400, bbox_inches='tight')
plt.show()

# %%
metrics = ["miss rate", "false alarm rate"]

records = []
for model, g in real_thresh_df.groupby("model"):
    # g = g.query("seed==0")
    base = g.query("thresh==0.5")  
    tuned = g.query("thresh!=0.5")
    for m in metrics:
        v0 = base[m].values[0]
        v1 = tuned[m].values[0]
        pct = 100 * (v1 - v0) / v0         # +% worse, −% better
        records.append({"model": model, "metric": m, "pct": pct})
delta_df = pd.DataFrame(records)

fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
sns.barplot(data=delta_df, x="model", y="pct", hue="metric",
            palette="tab10", errorbar=None, ax=ax)
# zero-line & label
ax.axhline(0, color="gray", linewidth=1, label="untuned baseline")

# annotate % on every bar
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        txt = f"{height:+.0f}%"
        if height == 0:
            txt = "0%"
        ax.text(bar.get_x() + bar.get_width()/2,
                height + (1.5 if height>=0 else -1.5),   # small offset
                txt, ha="center", va="bottom" if height>=0 else "top",
                fontsize=10)
ax.set_ylim(-120, 100)  # set y-axis limits
ax.set_ylabel("% change vs. untuned")
ax.set_xlabel("")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
ax.legend()
ax.grid(axis='x', alpha=0.5, which='both')
sns.despine()
plt.tight_layout()
plt.show()

# %%
metrics = ["miss rate", "false alarm rate"]

records = []
for model, g in thresh_df.groupby("model"):
    base = g.query("thresh==0.5")  
    tuned = g.query("thresh!=0.5")
    for m in metrics:
        v0 = base[m].values[0]
        v1 = tuned[m].values[0]
        pct = 100 * (v1 - v0) / v0         # +% worse, −% better
        records.append({"model": model, "metric": m, "pct": pct})
delta_df = pd.DataFrame(records)

fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
sns.barplot(data=delta_df, x="model", y="pct", hue="metric",
            palette="tab10", errorbar=None, ax=ax)
# zero-line & label
ax.axhline(0, color="gray", linewidth=1, label="untuned baseline")

# annotate % on every bar
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        txt = f"{height:+.0f}%"
        if height == 0:
            txt = "0%"
        ax.text(bar.get_x() + bar.get_width()/2,
                height + (1.5 if height>=0 else -1.5),   # small offset
                txt, ha="center", va="bottom" if height>=0 else "top",
                fontsize=10)
ax.set_ylim(-120, 100)  # set y-axis limits
ax.set_ylabel("% change vs. untuned")
ax.set_xlabel("")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
ax.legend()
ax.grid(axis='x', alpha=0.5, which='both')
sns.despine()
plt.tight_layout()
plt.show()
